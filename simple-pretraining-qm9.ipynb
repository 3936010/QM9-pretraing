# %%
# ! pip install torchvision rdkit-pypi

# %%
# Download dataset
# wget https://ndowloader.figshare.com/files/3195389 -O qm9.tar.gz
# tar -zxvf qm9.tar.gz

# %%
PATH_DATA = "" # path to the data

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
""" First install rdkit"""
#from rdkit import Chem
# from rdkit.Chem import AllChem

# %%
# Costom Dataset
class QM9Dataset(Dataset):
    def __init__(self, data_path):
        # load and process the data here
        pass
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        # implement how to get an item from the dataset
        pass

# def Moled
class MyModel(nn.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        # define Layers
    def forward(self, x):
        # define the forward pass
        pass

# %%
dataset = QM9Dataset(PATH_DATA)
model = MyModel()

# Loss function
loss = nn.MSELoss() #criterion
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Traing Loop
num_epochs = 100
for e in range(num_epochs):
    for data in DataLoader(dataset, batch_size=32, shuffle=True):
        inputs, targets = data
        outputs = model(inputs)
        loss = loss(outputs, targets)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# Save the pre-trained model
torch.save(model.state_dict(), 'pretrained_model_QM9.pth')
